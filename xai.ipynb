# %%
# %%capture
from xai import *

# %%
# 1. data
# load data
train_images, train_labels, test_images, test_labels = mnist_data()
samples, sample_labels = sample_and_categorize(train_images, train_labels, number=3000)
samples_test, sample_labels_test = sample_and_categorize(test_images, test_labels, number=len(test_labels))
print(samples.shape)
print(sample_labels.shape)

# reshape data
x_train = np.reshape(samples, (-1, 784))
# x_train = np.reshape(train_images, (-1, 784))
print(x_train.shape)
# Out:
# (3000, 28, 28, 1)
# (3000,)
# (3000, 784)

# %%
# 2. model: train a VAE
# model_pre = VAE(latent_dim=12)

# Fit the model. Note that the 'eps' input is ignored because it is an Input tensor.

# dummy_eps_input = np.zeros((len(x_train), model_pre.latent_dim))
# history = model_pre.model.fit([x_train, dummy_eps_input], x_train, shuffle=True, epochs=50, batch_size=100)
# plot_learning_curve(history)
# model_pre.save()

# %%
vae = VAE.load("trained_models")
cnn = load_model("trained_models/classifier.h5")
xai = xai_model(vae.decoder, cnn, input_shape=(12,))
xai.summary()
# Out:
# 2024-03-22 11:06:45.261484: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.271471: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.272037: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.273527: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-22 11:06:45.274079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.274613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.275105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.767357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.767724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.768073: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-22 11:06:45.768343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6479 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 12)]              0
# _________________________________________________________________
# sequential (Sequential)      (None, 784)               408848
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28, 1)         0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 10)                454922
# =================================================================
# Total params: 863,770
# Trainable params: 863,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
view_samples = samples_test
view_sample_labels = sample_labels_test
# view_samples = samples
# view_sample_labels = sample_labels

# %%
    x_view = np.reshape(view_samples, (-1, 784))
    y_view_onehot = tf.one_hot(tf.constant(view_sample_labels), depth=10).numpy()
    h_view = vae.encoder.predict(x_view)
# Out:
# 2024-03-22 11:06:46.571834: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
    count = 10
    for i in range(len(x_view)):
        x = np.array([h_view[i]])
        y = np.array([y_view_onehot[i]])
        g = gradient_of_x(x, y, xai)
        # g = saliency_of_x(x, xai)

        g_npy = np.squeeze(g.numpy())
        plot_image_and_gradient(np.reshape(x_view[i], (28, 28)), g_npy)
        # plot_image_and_gradient(np.reshape(x_view[i], (28, 28)), g_npy, title="Saliency of hidden vector")

        # Identify the maximum gradient entry
        max_grad_index = np.argmax(np.abs(g_npy))
        # latent_space_display(x, vae.decoder, highlight_dim=max_grad_index)
        latent_space_display_mark(x, view_sample_labels[i], vae.decoder, xai, highlight_dim=int(max_grad_index))

        if count <= 0:
            break
        count -= 1
# Out:
# 2024-03-22 11:06:47.651480: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2024-03-22 11:06:48.013387: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x7fb4e1867b80> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 ctx = (renderer._draw_disabled()
#    2190        if hasattr(renderer, '_draw_disabled')
#    2191        else suppress())
#    2192 with ctx:
# -> 2193     self.figure.draw(renderer)
#    2195 bbox_inches = self.figure.get_tightbbox(
#    2196     renderer, bbox_extra_artists=bbox_extra_artists)
#    2197 if pad_inches is None:
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/figure.py:1863, in Figure.draw(self, renderer)
#    1860             # ValueError can occur when resizing a window.
#    1862     self.patch.draw(renderer)
# -> 1863     mimage._draw_list_compositing_images(
#    1864         renderer, self, artists, self.suppressComposite)
#    1866     renderer.close_group('figure')
#    1867 finally:
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/cbook/deprecation.py:411, in _delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     401     deprecation_addendum = (
#     402         f"If any parameter follows {name!r}, they should be passed as "
#     403         f"keyword, not positionally.")
#     404     warn_deprecated(
#     405         since,
#     406         name=repr(name),
#    (...)
#     409                  else deprecation_addendum,
#     410         **kwargs)
# --> 411 return func(*inner_args, **inner_kwargs)
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/axes/_base.py:2747, in _AxesBase.draw(self, renderer, inframe)
#    2744         a.draw(renderer)
#    2745     renderer.stop_rasterizing()
# -> 2747 mimage._draw_list_compositing_images(renderer, self, artists)
#    2749 renderer.close_group('axes')
#    2750 self.stale = False
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/axis.py:1176, in Axis.draw(self, renderer, *args, **kwargs)
#    1169     tick.draw(renderer)
#    1171 # scale up the axis label box to also find the neighbors, not
#    1172 # just the tick labels that actually overlap note we need a
#    1173 # *copy* of the axis label box because we don't want to scale
#    1174 # the actual bbox
# -> 1176 self._update_label_position(renderer)
#    1178 self.label.draw(renderer)
#    1180 self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/axis.py:2061, in XAxis._update_label_position(self, renderer)
#    2057     return
#    2059 # get bounding boxes for this axis and any siblings
#    2060 # that have been set by `fig.align_xlabels()`
# -> 2061 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2063 x, y = self.label.get_position()
#    2064 if self.label_position == 'bottom':
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/axis.py:2046, in XAxis._get_tick_boxes_siblings(self, renderer)
#    2044 for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2045     ticks_to_draw = axx.xaxis._update_ticks()
# -> 2046     tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2047     bboxes.extend(tlb)
#    2048     bboxes2.extend(tlb2)
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/axis.py:1091, in Axis._get_tick_bboxes(self, ticks, renderer)
#    1089 def _get_tick_bboxes(self, ticks, renderer):
#    1090     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091     return ([tick.label1.get_window_extent(renderer)
#    1092              for tick in ticks if tick.label1.get_visible()],
#    1093             [tick.label2.get_window_extent(renderer)
#    1094              for tick in ticks if tick.label2.get_visible()])
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/axis.py:1091, in <listcomp>(.0)
#    1089 def _get_tick_bboxes(self, ticks, renderer):
#    1090     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091     return ([tick.label1.get_window_extent(renderer)
#    1092              for tick in ticks if tick.label1.get_visible()],
#    1093             [tick.label2.get_window_extent(renderer)
#    1094              for tick in ticks if tick.label2.get_visible()])
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/text.py:905, in Text.get_window_extent(self, renderer, dpi)
#     903 x, y = self.get_unitless_position()
#     904 x, y = self.get_transform().transform((x, y))
# --> 905 bbox = bbox.translated(x, y)
#     906 return bbox
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/transforms.py:635, in BboxBase.translated(self, tx, ty)
#     633 def translated(self, tx, ty):
#     634     """Construct a `Bbox` by translating this one by *tx* and *ty*."""
# --> 635     return Bbox(self._points + (tx, ty))
#
# File ~/anaconda3/envs/congyuAI/lib/python3.9/site-packages/matplotlib/transforms.py:784, in Bbox.__init__(self, points, **kwargs)
#     780 self._ignore = True
#     781 # it is helpful in some contexts to know if the bbox is a
#     782 # default or has been mutated; we store the orig points to
#     783 # support the mutated methods
# --> 784 self._points_orig = self._points.copy()
#
# KeyboardInterrupt:
